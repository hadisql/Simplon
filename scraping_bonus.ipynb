# %% [markdown]
# ### Scraping du Blog : https://www.charlesbordet.com/fr/blog/
#
# "Scraping en cascade"
# - Scraper la page suivante: https://www.charlesbordet.com/fr/blog/
# - Récupérer la liste des articles
# - Pour chaque articles retrouver l'url vers la page dédiée à cet article (par exemple pour le 1er article l'adresse est : https://www.charlesbordet.com/fr/reactive-shiny/)
# - Une fois arrivé sur cette page récupérer le sommaire
# - Produire une liste d'articles comprenant
#     - Le titre
#     - La description
#     - Le tps de lecture
#     - (Et surtout) le sommaire (modifié)

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %% [markdown]
# ### Je résume dans une fonction le ***scrapping du sommaire*** (pour l'appliquer après à chaque article) :

# %%
def scrap_sommaire(url, sub_url):
    sub_page = requests.get(url+sub_url) 
    soup = bs(sub_page.content,'html.parser') 
    sommaire = soup.select(".toc__menu") # class concernant le Sommaire
    
    sommaire_dict = {'Sommaire':[]}
    for list in sommaire[0]:
        if list.ul:
            sommaire_dict['Sommaire'].append(list.find("a").get_text())
            for sublist in list.ul:
                sommaire_dict['Sommaire'].append(sublist.find("a").get_text())
        else:
            sommaire_dict['Sommaire'].append(list.find("a").get_text())
        
    return pd.DataFrame(sommaire_dict)

# %% [markdown]
# ### Boucle sur **CHAQUE ARTICLE** de la page principale : on stocke le titre, l'URL, la description, le temps de lecture, ET le sommaire en format DataFrame Pandas (autre méthode possible)

# %%
welcome_url = "https://www.charlesbordet.com"
welcome_page = requests.get(welcome_url+"/fr/blog/")
welcome_soup = bs(welcome_page.content, 'html.parser')

liste_articles = welcome_soup.select(".list__item")             #rassemble TOUS les articles de la page principale
article_titles = welcome_soup.select(".archive__item-title")    #rassemble les titres avec url de chaque article

articles_infos = []
for i in range(len(article_titles)):    #on boucle sur le nombre d'article recensé dans la page d'accueil
    
    title = article_titles[i].find("a").get_text()
    description = liste_articles[i].select(".archive__item-excerpt")[0].text
    reading_time = liste_articles[i].select(".page__meta")[0].get_text().strip()
    sub_url = article_titles[i].find("a").get("href")
    sommaire = scrap_sommaire(welcome_url, sub_url) # fonction 'scrap_sommaire' qui boucle sur les url
    articles_infos.append({'Title': title,
                           'Description': description,
                           'Temps de lecture': reading_time,
                           'URL': sub_url,
                           'Sommaire': sommaire})

articles_infos #liste de dictionnaires contenant 'Titre/Description/url'
# Out:
# [{'Title': 'Le guide complet pour comprendre la réactivité en Shiny\n',
#   'Description': 'Comprendre la réactivité en Shiny est fondamental pour être capable de créer des applications complexes mais performantes et faciles à maintenir.\n',
#   'Temps de lecture': '51 minutes de lecture',
#   'URL': '/fr/reactive-shiny/',
#   'Sommaire':                                              Sommaire
#   0                          C’est quoi la réactivité ?
#   1    Les fonctions de réactivité : req, isolate, etc.
#   2                              La fonction reactive()
#   3                         La fonction eventReactive()
#   4                               La fonction observe()
#   5                          La fonction observeEvent()
#   6                        La fonction reactiveValues()
#   7                               La fonction isolate()
#   8                                   La fonction req()
#   9         Mes petites astuces autour de la réactivité
#   10       Comment forcer la réactivité avec Sys.time()
#   11         Comment accélérer un calcul avec bindCache
#   12  Comment avoir plusieurs inputs dans un observe...
#   13                Cas d'usage: Dans un shinydashboard
#   14           Cas d'usage: Les filtres interdépendants
#   15           Solution 1 : Supprimer l’interdépendance
#   16                     Solution 2 : Ajouter un bouton
#   17  Solution 3 : Filtres emboîtés avec garantie de...
#   18  Solution 4 : Filtres emboîtés sans garantie de...
#   19  Solution 5 : Si les filtres sont rapides à cal...},
#  {'Title': 'Comment upgrader R 4.0.0 sur Debian\n',
#   'Description': 'Je suis récemment passé à R 4.0.0 sur mes serveurs Debian. Sauf que la mise à jour n’était pas facile, alors je partage dans cet article comment j’ai fait.\n',
#   'Temps de lecture': '3 minutes de lecture',
#   'URL': '/fr/comment-upgrader-R-4-0-0-sur-debian/',
#   'Sommaire':                  Sommaire
#   0      Le point de départ
#   1       La solution naïve
#   2  La solution qui marche},
#  {'Title': 'Le guide ultime pour déployer une application Shiny sur AWS\n',
#   'Description': 'Vous souhaitez déployer une application Shiny sur AWS\xa0? Dans ce guide complet, je vous explique pas à pas comment faire. En bonus, le guide est téléchargeable\xa0!\n',
#   'Temps de lecture': '63 minutes de lecture',
#   'URL': '/fr/guide-shiny-aws/',
#   'Sommaire':                                              Sommaire
#   0                                               Intro
#   1                               La méthode « galère »
#   2                           La méthode « qui marche »
#   3                   À quoi s'attendre dans ce guide ?
#   4                      1. Créer une application Shiny
#   5                         2. Créer un serveur sur AWS
#   6             Créer votre compte gratuitement sur AWS
#   7                 Créer votre premier serveur sur EC2
#   8                         Étape 1 : Choisir votre AMI
#   9             Étape 2 : Choisir votre type d'instance
#   10       Étape 3 : Choisir votre taille de disque dur
#   11                Étape 4 : Créez une clé de sécurité
#   12  3. Installer R et R Shiny sur votre nouveau se...
#   13          Comment accéder à votre nouveau serveur ?
#   14                   Comment installer Shiny Server ?
#   15           4. Déployer l’application sur le serveur
#   16  1. Comment accéder à l'application Shiny insta...
#   17  2. Télécharger l'application sur le serveur à ...
#   18      3. Créer un raccourci dans /srv/shiny-server/
#   19  4. Comment débugger une appli Shiny à partir d...
#   20            5. Extra : Créer un nom de domaine cool
#   21                       1. Trouver un nom de domaine
#   22                              2. Paramétrer les DNS
#   23                3. Mettre en place un reverse proxy
#   24    6. Extra : Sécuriser votre application en HTTPS
#   25                             Le HTTPS, c’est quoi ?
#   26     Créer un certificat SSL/TLS avec Let's Encrypt
#   27  Comment installer un certificat SSL/TLS avec n...
#   28              Comment forcer l’utilisation de HTTPS
#   29  7. Extra : Protéger votre application avec un ...
#   30                                Les choix possibles
#   31    Utiliser nginx comme serveur d’authentification
#   32    Utiliser auth0 comme serveur d’authentification
#   33  Comment créer votre portail d'authentification...
#   34                                   Comparatif final},
#  {'Title': 'useR!2019: Retours sur la conférence useR de l’année\n',
#   'Description': 'La conférence useR!2019 est maintenant terminée. Vous l’avez manquée ? Dans cet article, je vous montre ce qui s’est passé, quels sont les temps forts et les bonnes nouvelles que vous avez manquées !\n',
#   'Temps de lecture': '12 minutes de lecture',
#   'URL': '/fr/useR-2019-report/',
#   'Sommaire':                                              Sommaire
#   0                                           Tutoriels
#   1   Le Machine Learning automatique et transparent...
#   2   Docker pour la Data Science : R, ShinyProxy et...
#   3                                 Qui était présent ?
#   4   Cynkra, une société zurichoise de consulting s...
#   5   MiraiSolutions, une autre société de consultin...
#   6   Appsilon, une solution complète de consulting ...
#   7   Jumping Rivers, Formation et consulting en Dat...
#   8   ThinkR, Expertise et Formation sur l’environne...
#   9                                  Packages à essayer
#   10  `shinyEventLogger` : Le Logging dans les appli...
#   11  `promises` : Abstractions pour la programmatio...
#   12  `future` : L'Unified Parallel et le Distribute...
#   13  `shinymeta` : Enregistrer et exposer la logiqu...
#   14                  `polite` : Soyez sympa sur le web
#   15          `SuperLearner` : Prédiction Super Learner
#   16  `auth0` : Authentification sécurisée dans Shin...
#   17                                           Au final},
#  {'Title': 'user! 2019 : Qu’attendre et comment se préparer pour la conférence ?\n',
#   'Description': 'user!2019 commence la semaine prochaine. Comment ça va se passer ? Comment se préparer ? Dans cet article, je présente mes objectifs et attentes.\n',
#   'Temps de lecture': '7 minutes de lecture',
#   'URL': '/fr/useR-2019-toulouse/',
#   'Sommaire':                                  Sommaire
#   0                1. Tutorials : Apprendre
#   1               2. Conférences: Découvrir
#   2  3. Les enthousiastes de R : Rencontrer},
#  {'Title': 'Comment faire de beaux graphiques avec R et ggplot2\n',
#   'Description': 'Mes premiers graphes en R étaient horribles… Je pensais que les graphes en R n’étaient utilisables que pour des articles scientifiques. Eh bien non. Aujourd’hui, même la BBC utilise R pour créer des graphiques prêts à la publication. Découvrez comment dans cet article !\n',
#   'Temps de lecture': '12 minutes de lecture',
#   'URL': '/fr/faire-beaux-graphiques-ggplot2/',
#   'Sommaire':                                              Sommaire
#   0                             De quoi R est capable ?
#   1                                   Le package bbplot
#   2                                 Essayons le package
#   3             Que peut-on apprendre de leur package ?
#   4   Comment faire un beau graphique avec ggplot2 e...
#   5                    Itération 0 - Le point de départ
#   6                      Itération 1 - Ajouter un titre
#   7       Itération 2 - Améliorer les libellés des axes
#   8       Itération 3 - Ajouter une ligne de régression
#   9   Itération 4 - Ajouter des couleurs pour chaque...
#   10      Iteration 5 - Améliorer la légende de couleur
#   11           Iteration 6 - Faire les choix difficiles
#   12              Iteration 7 - Ajouter des annotations},
#  {'Title': 'Comprendre la descente de gradient en 3 étapes et 12 dessins\n',
#   'Description': 'Tout le monde a déjà entendu parler de l’algorithme de descente de gradient, mais… savez-vous vraiment comment ça marche et l’avez-vous déjà implémenté par vous-même pour être sûr d’avoir bien compris comment ça marche ? Cet article explique en images pourquoi on l’utilise, comment ça marche, et vous montre même une implémentation en Python !\n',
#   'Temps de lecture': '9 minutes de lecture',
#   'URL': '/fr/gradient-descent/',
#   'Sommaire':                                             Sommaire
#   0               C’est quoi la descente de gradient ?
#   1                                Comment ça marche ?
#   2                       Et les maths, dans tout ça ?
#   3                                Les pièges à éviter
#   4            Comment fixer le taux d’apprentissage ?
#   5  Comment régler le problème du *vanishing gradi...
#   6          Comment lutter contre les minima locaux ?
#   7                                           Ensuite…},
#  {'Title': 'Comment extraire et analyser les données de fichiers PDF en R\n',
#   'Description': 'R est un outil formidable pour faire du text mining. Encore faut-il pouvoir extraire le texte de vos documents PDF ! Cet article explique exactement comment faire, et aussi comment préparer vos données pour l’analyse !\n',
#   'Temps de lecture': '10 minutes de lecture',
#   'URL': '/fr/extract-pdf/',
#   'Sommaire':                                             Sommaire
#   0                        Pourquoi des fichiers PDF ?
#   1  Deux techniques pour extraire le texte des fic...
#   2          Première technique : `pdftools::pdf_text`
#   3               Deuxième technique : Le package `tm`
#   4                       Extraire l’information utile
#   5          1. Nettoyer les en-têtes et pieds de page
#   6          2. Concaténer les deux colonnes ensemble.
#   7   3. Trouver les lignes avec les noms des orateurs},
#  {'Title': 'Startup SaaS : Comment prédire la LTV d’un nouvel utilisateur ?\n',
#   'Description': 'Si vous avez un produit SaaS, vous vous êtes forcément déjà posé la question : Comment connaître la valeur d’un nouvel utilisateur ? Comment prédire son churn rate ? Dans cet article, j’explique comment un statisticien peut répondre à ces questions pour vous.\n',
#   'Temps de lecture': '10 minutes de lecture',
#   'URL': '/fr/comment-predire-ltv-pour-startup-saas/',
#   'Sommaire':                                            Sommaire
#   0                  Présentation de la start-up SaaS
#   1                      Étude de la rétention client
#   2                                L'approche biaisée
#   3            L'approche que c'est une mauvaise idée
#   4  La bonne approche avec Messieurs Kaplan et Meier
#   5                 D'autres résultats intéressants :
#   6                                           Suite ?},
#  {'Title': 'L’Algèbre Linéaire pour la Data Science : Pourquoi ?\n',
#   'Description': 'On me demande souvent quels sont les pré-requis mathématiques à connaître pour la data science. L’algèbre linéaire est une des disciplines les plus importantes à connaître ! Je commence donc cette série d’articles sur les concepts essentiels à connaître. Que vous soyez novice ou ayez simplement besoin d’une petite révision, c’est pour vous !\n',
#   'Temps de lecture': '8 minutes de lecture',
#   'URL': '/fr/linear-algebra/',
#   'Sommaire':                                   Sommaire
#   0      À quoi ça sert l'Algèbre Linéaire ?
#   1                Pourquoi s'y intéresser ?
#   2  C'est quoi l'algèbre linéaire en fait ?}]

# %%
articles_infos
# Out:
# [{'Title': 'Le guide complet pour comprendre la réactivité en Shiny\n',
#   'Description': 'Comprendre la réactivité en Shiny est fondamental pour être capable de créer des applications complexes mais performantes et faciles à maintenir.\n',
#   'Temps de lecture': '51 minutes de lecture',
#   'URL': '/fr/reactive-shiny/',
#   'Sommaire':                                              Sommaire
#   0                          C’est quoi la réactivité ?
#   1    Les fonctions de réactivité : req, isolate, etc.
#   2                              La fonction reactive()
#   3                         La fonction eventReactive()
#   4                               La fonction observe()
#   5                          La fonction observeEvent()
#   6                        La fonction reactiveValues()
#   7                               La fonction isolate()
#   8                                   La fonction req()
#   9         Mes petites astuces autour de la réactivité
#   10       Comment forcer la réactivité avec Sys.time()
#   11         Comment accélérer un calcul avec bindCache
#   12  Comment avoir plusieurs inputs dans un observe...
#   13                Cas d'usage: Dans un shinydashboard
#   14           Cas d'usage: Les filtres interdépendants
#   15           Solution 1 : Supprimer l’interdépendance
#   16                     Solution 2 : Ajouter un bouton
#   17  Solution 3 : Filtres emboîtés avec garantie de...
#   18  Solution 4 : Filtres emboîtés sans garantie de...
#   19  Solution 5 : Si les filtres sont rapides à cal...},
#  {'Title': 'Comment upgrader R 4.0.0 sur Debian\n',
#   'Description': 'Je suis récemment passé à R 4.0.0 sur mes serveurs Debian. Sauf que la mise à jour n’était pas facile, alors je partage dans cet article comment j’ai fait.\n',
#   'Temps de lecture': '3 minutes de lecture',
#   'URL': '/fr/comment-upgrader-R-4-0-0-sur-debian/',
#   'Sommaire':                  Sommaire
#   0      Le point de départ
#   1       La solution naïve
#   2  La solution qui marche},
#  {'Title': 'Le guide ultime pour déployer une application Shiny sur AWS\n',
#   'Description': 'Vous souhaitez déployer une application Shiny sur AWS\xa0? Dans ce guide complet, je vous explique pas à pas comment faire. En bonus, le guide est téléchargeable\xa0!\n',
#   'Temps de lecture': '63 minutes de lecture',
#   'URL': '/fr/guide-shiny-aws/',
#   'Sommaire':                                              Sommaire
#   0                                               Intro
#   1                               La méthode « galère »
#   2                           La méthode « qui marche »
#   3                   À quoi s'attendre dans ce guide ?
#   4                      1. Créer une application Shiny
#   5                         2. Créer un serveur sur AWS
#   6             Créer votre compte gratuitement sur AWS
#   7                 Créer votre premier serveur sur EC2
#   8                         Étape 1 : Choisir votre AMI
#   9             Étape 2 : Choisir votre type d'instance
#   10       Étape 3 : Choisir votre taille de disque dur
#   11                Étape 4 : Créez une clé de sécurité
#   12  3. Installer R et R Shiny sur votre nouveau se...
#   13          Comment accéder à votre nouveau serveur ?
#   14                   Comment installer Shiny Server ?
#   15           4. Déployer l’application sur le serveur
#   16  1. Comment accéder à l'application Shiny insta...
#   17  2. Télécharger l'application sur le serveur à ...
#   18      3. Créer un raccourci dans /srv/shiny-server/
#   19  4. Comment débugger une appli Shiny à partir d...
#   20            5. Extra : Créer un nom de domaine cool
#   21                       1. Trouver un nom de domaine
#   22                              2. Paramétrer les DNS
#   23                3. Mettre en place un reverse proxy
#   24    6. Extra : Sécuriser votre application en HTTPS
#   25                             Le HTTPS, c’est quoi ?
#   26     Créer un certificat SSL/TLS avec Let's Encrypt
#   27  Comment installer un certificat SSL/TLS avec n...
#   28              Comment forcer l’utilisation de HTTPS
#   29  7. Extra : Protéger votre application avec un ...
#   30                                Les choix possibles
#   31    Utiliser nginx comme serveur d’authentification
#   32    Utiliser auth0 comme serveur d’authentification
#   33  Comment créer votre portail d'authentification...
#   34                                   Comparatif final},
#  {'Title': 'useR!2019: Retours sur la conférence useR de l’année\n',
#   'Description': 'La conférence useR!2019 est maintenant terminée. Vous l’avez manquée ? Dans cet article, je vous montre ce qui s’est passé, quels sont les temps forts et les bonnes nouvelles que vous avez manquées !\n',
#   'Temps de lecture': '12 minutes de lecture',
#   'URL': '/fr/useR-2019-report/',
#   'Sommaire':                                              Sommaire
#   0                                           Tutoriels
#   1   Le Machine Learning automatique et transparent...
#   2   Docker pour la Data Science : R, ShinyProxy et...
#   3                                 Qui était présent ?
#   4   Cynkra, une société zurichoise de consulting s...
#   5   MiraiSolutions, une autre société de consultin...
#   6   Appsilon, une solution complète de consulting ...
#   7   Jumping Rivers, Formation et consulting en Dat...
#   8   ThinkR, Expertise et Formation sur l’environne...
#   9                                  Packages à essayer
#   10  `shinyEventLogger` : Le Logging dans les appli...
#   11  `promises` : Abstractions pour la programmatio...
#   12  `future` : L'Unified Parallel et le Distribute...
#   13  `shinymeta` : Enregistrer et exposer la logiqu...
#   14                  `polite` : Soyez sympa sur le web
#   15          `SuperLearner` : Prédiction Super Learner
#   16  `auth0` : Authentification sécurisée dans Shin...
#   17                                           Au final},
#  {'Title': 'user! 2019 : Qu’attendre et comment se préparer pour la conférence ?\n',
#   'Description': 'user!2019 commence la semaine prochaine. Comment ça va se passer ? Comment se préparer ? Dans cet article, je présente mes objectifs et attentes.\n',
#   'Temps de lecture': '7 minutes de lecture',
#   'URL': '/fr/useR-2019-toulouse/',
#   'Sommaire':                                  Sommaire
#   0                1. Tutorials : Apprendre
#   1               2. Conférences: Découvrir
#   2  3. Les enthousiastes de R : Rencontrer},
#  {'Title': 'Comment faire de beaux graphiques avec R et ggplot2\n',
#   'Description': 'Mes premiers graphes en R étaient horribles… Je pensais que les graphes en R n’étaient utilisables que pour des articles scientifiques. Eh bien non. Aujourd’hui, même la BBC utilise R pour créer des graphiques prêts à la publication. Découvrez comment dans cet article !\n',
#   'Temps de lecture': '12 minutes de lecture',
#   'URL': '/fr/faire-beaux-graphiques-ggplot2/',
#   'Sommaire':                                              Sommaire
#   0                             De quoi R est capable ?
#   1                                   Le package bbplot
#   2                                 Essayons le package
#   3             Que peut-on apprendre de leur package ?
#   4   Comment faire un beau graphique avec ggplot2 e...
#   5                    Itération 0 - Le point de départ
#   6                      Itération 1 - Ajouter un titre
#   7       Itération 2 - Améliorer les libellés des axes
#   8       Itération 3 - Ajouter une ligne de régression
#   9   Itération 4 - Ajouter des couleurs pour chaque...
#   10      Iteration 5 - Améliorer la légende de couleur
#   11           Iteration 6 - Faire les choix difficiles
#   12              Iteration 7 - Ajouter des annotations},
#  {'Title': 'Comprendre la descente de gradient en 3 étapes et 12 dessins\n',
#   'Description': 'Tout le monde a déjà entendu parler de l’algorithme de descente de gradient, mais… savez-vous vraiment comment ça marche et l’avez-vous déjà implémenté par vous-même pour être sûr d’avoir bien compris comment ça marche ? Cet article explique en images pourquoi on l’utilise, comment ça marche, et vous montre même une implémentation en Python !\n',
#   'Temps de lecture': '9 minutes de lecture',
#   'URL': '/fr/gradient-descent/',
#   'Sommaire':                                             Sommaire
#   0               C’est quoi la descente de gradient ?
#   1                                Comment ça marche ?
#   2                       Et les maths, dans tout ça ?
#   3                                Les pièges à éviter
#   4            Comment fixer le taux d’apprentissage ?
#   5  Comment régler le problème du *vanishing gradi...
#   6          Comment lutter contre les minima locaux ?
#   7                                           Ensuite…},
#  {'Title': 'Comment extraire et analyser les données de fichiers PDF en R\n',
#   'Description': 'R est un outil formidable pour faire du text mining. Encore faut-il pouvoir extraire le texte de vos documents PDF ! Cet article explique exactement comment faire, et aussi comment préparer vos données pour l’analyse !\n',
#   'Temps de lecture': '10 minutes de lecture',
#   'URL': '/fr/extract-pdf/',
#   'Sommaire':                                             Sommaire
#   0                        Pourquoi des fichiers PDF ?
#   1  Deux techniques pour extraire le texte des fic...
#   2          Première technique : `pdftools::pdf_text`
#   3               Deuxième technique : Le package `tm`
#   4                       Extraire l’information utile
#   5          1. Nettoyer les en-têtes et pieds de page
#   6          2. Concaténer les deux colonnes ensemble.
#   7   3. Trouver les lignes avec les noms des orateurs},
#  {'Title': 'Startup SaaS : Comment prédire la LTV d’un nouvel utilisateur ?\n',
#   'Description': 'Si vous avez un produit SaaS, vous vous êtes forcément déjà posé la question : Comment connaître la valeur d’un nouvel utilisateur ? Comment prédire son churn rate ? Dans cet article, j’explique comment un statisticien peut répondre à ces questions pour vous.\n',
#   'Temps de lecture': '10 minutes de lecture',
#   'URL': '/fr/comment-predire-ltv-pour-startup-saas/',
#   'Sommaire':                                            Sommaire
#   0                  Présentation de la start-up SaaS
#   1                      Étude de la rétention client
#   2                                L'approche biaisée
#   3            L'approche que c'est une mauvaise idée
#   4  La bonne approche avec Messieurs Kaplan et Meier
#   5                 D'autres résultats intéressants :
#   6                                           Suite ?},
#  {'Title': 'L’Algèbre Linéaire pour la Data Science : Pourquoi ?\n',
#   'Description': 'On me demande souvent quels sont les pré-requis mathématiques à connaître pour la data science. L’algèbre linéaire est une des disciplines les plus importantes à connaître ! Je commence donc cette série d’articles sur les concepts essentiels à connaître. Que vous soyez novice ou ayez simplement besoin d’une petite révision, c’est pour vous !\n',
#   'Temps de lecture': '8 minutes de lecture',
#   'URL': '/fr/linear-algebra/',
#   'Sommaire':                                   Sommaire
#   0      À quoi ça sert l'Algèbre Linéaire ?
#   1                Pourquoi s'y intéresser ?
#   2  C'est quoi l'algèbre linéaire en fait ?}]

# %%
articles_infos[0]['Sommaire']
# Out:
#                                              Sommaire
# 0                          C’est quoi la réactivité ?
# 1    Les fonctions de réactivité : req, isolate, etc.
# 2                              La fonction reactive()
# 3                         La fonction eventReactive()
# 4                               La fonction observe()
# 5                          La fonction observeEvent()
# 6                        La fonction reactiveValues()
# 7                               La fonction isolate()
# 8                                   La fonction req()
# 9         Mes petites astuces autour de la réactivité
# 10       Comment forcer la réactivité avec Sys.time()
# 11         Comment accélérer un calcul avec bindCache
# 12  Comment avoir plusieurs inputs dans un observe...
# 13                Cas d'usage: Dans un shinydashboard
# 14           Cas d'usage: Les filtres interdépendants
# 15           Solution 1 : Supprimer l’interdépendance
# 16                     Solution 2 : Ajouter un bouton
# 17  Solution 3 : Filtres emboîtés avec garantie de...
# 18  Solution 4 : Filtres emboîtés sans garantie de...
# 19  Solution 5 : Si les filtres sont rapides à cal...

# %%
url + articles_infos[0]['url']
# Out:
# 'https://www.charlesbordet.com/fr/reactive-shiny/'

# %%
test = articles_infos[0] #reactive-shiny
sub_page = requests.get(url+test['url']) 
soup = bs(sub_page.content,'html.parser') 
sommaire = soup.select(".toc__menu") # class concernant le Sommaire

# %%
test
# Out:
# {'Title': 'Le guide complet pour comprendre la réactivité en Shiny\n',
#  'Description': 'Comprendre la réactivité en Shiny est fondamental pour être capable de créer des applications complexes mais performantes et faciles à maintenir.\n',
#  'Temps de lecture': '51 minutes de lecture',
#  'url': '/fr/reactive-shiny/'}

# %%
sommaire[0]
# Out:
# <ul class="toc__menu"><li><a href="#c-est-quoi-la-reactivite">C’est quoi la réactivité ?</a></li><li><a href="#les-fonctions-de-reactivite-req-isolate-etc">Les fonctions de réactivité : req, isolate, etc.</a><ul><li><a href="#la-fonction-reactive">La fonction reactive()</a></li><li><a href="#la-fonction-eventreactive">La fonction eventReactive()</a></li><li><a href="#la-fonction-observe">La fonction observe()</a></li><li><a href="#la-fonction-observeevent">La fonction observeEvent()</a></li><li><a href="#la-fonction-reactivevalues">La fonction reactiveValues()</a></li><li><a href="#la-fonction-isolate">La fonction isolate()</a></li><li><a href="#la-fonction-req">La fonction req()</a></li></ul></li><li><a href="#mes-petites-astuces-autour-de-la-reactivite">Mes petites astuces autour de la réactivité</a><ul><li><a href="#comment-forcer-la-reactivite-avec-sys-time">Comment forcer la réactivité avec Sys.time()</a></li><li><a href="#comment-accelerer-un-calcul-avec-bindcache">Comment accélérer un calcul avec bindCache</a></li><li><a href="#comment-avoir-plusieurs-inputs-dans-un-observeevent">Comment avoir plusieurs inputs dans un observeEvent</a></li></ul></li><li><a href="#dans-un-shinydashboard">Cas d'usage: Dans un shinydashboard</a></li><li><a href="#les-filtres-interdependants">Cas d'usage: Les filtres interdépendants</a><ul><li><a href="#solution-1-supprimer-l-interdependance">Solution 1 : Supprimer l’interdépendance</a></li><li><a href="#solution-2-ajouter-un-bouton">Solution 2 : Ajouter un bouton</a></li><li><a href="#solution-3-filtres-emboites-avec-garantie-de-changement">Solution 3 : Filtres emboîtés avec garantie de changement</a></li><li><a href="#solution-4-filtres-emboites-sans-garantie-de-changement">Solution 4 : Filtres emboîtés sans garantie de changement</a></li><li><a href="#solution-5-si-les-filtres-sont-rapides-a-calculer">Solution 5 : Si les filtres sont rapides à calculer</a></li></ul></li></ul>

# %% [markdown]
# ### Récupération du sommaire

# %%
sommaire_dict = {'Sommaire':[]}
print('Sommaire')
for list in sommaire[0]:
    if list.ul:
        print('liste avec sous-liste :',list.find("a").get_text())
        sommaire_dict['Sommaire'].append(list.find("a").get_text())
        for sublist in list.ul:
            print('* :', sublist.find("a").get_text())
            sommaire_dict['Sommaire'].append(sublist.find("a").get_text())
    else:
        print(list.find("a").get_text(),'\n')
        sommaire_dict['Sommaire'].append(list.find("a").get_text())
# Out:
# Sommaire
# C’est quoi la réactivité ?
#
# liste avec sous-liste : Les fonctions de réactivité : req, isolate, etc.
# * : La fonction reactive()
# * : La fonction eventReactive()
# * : La fonction observe()
# * : La fonction observeEvent()
# * : La fonction reactiveValues()
# * : La fonction isolate()
# * : La fonction req()
# liste avec sous-liste : Mes petites astuces autour de la réactivité
# * : Comment forcer la réactivité avec Sys.time()
# * : Comment accélérer un calcul avec bindCache
# * : Comment avoir plusieurs inputs dans un observeEvent
# Cas d'usage: Dans un shinydashboard
#
# liste avec sous-liste : Cas d'usage: Les filtres interdépendants
# * : Solution 1 : Supprimer l’interdépendance
# * : Solution 2 : Ajouter un bouton
# * : Solution 3 : Filtres emboîtés avec garantie de changement
# * : Solution 4 : Filtres emboîtés sans garantie de changement
# * : Solution 5 : Si les filtres sont rapides à calculer

# %%
df_0 = pd.DataFrame(sommaire_dict)

# %%
df_0
# Out:
#                                              Sommaire
# 0                          C’est quoi la réactivité ?
# 1    Les fonctions de réactivité : req, isolate, etc.
# 2                              La fonction reactive()
# 3                         La fonction eventReactive()
# 4                               La fonction observe()
# 5                          La fonction observeEvent()
# 6                        La fonction reactiveValues()
# 7                               La fonction isolate()
# 8                                   La fonction req()
# 9         Mes petites astuces autour de la réactivité
# 10       Comment forcer la réactivité avec Sys.time()
# 11         Comment accélérer un calcul avec bindCache
# 12  Comment avoir plusieurs inputs dans un observe...
# 13                Cas d'usage: Dans un shinydashboard
# 14           Cas d'usage: Les filtres interdépendants
# 15           Solution 1 : Supprimer l’interdépendance
# 16                     Solution 2 : Ajouter un bouton
# 17  Solution 3 : Filtres emboîtés avec garantie de...
# 18  Solution 4 : Filtres emboîtés sans garantie de...
# 19  Solution 5 : Si les filtres sont rapides à cal...
